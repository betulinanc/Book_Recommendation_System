# %%
import gzip

# %%
with gzip.open("goodreads_books.json.gz", 'r') as f:
    line = f.readline()

# %%
line
# Out:
# b'{"isbn": "0312853122", "text_reviews_count": "1", "series": [], "country_code": "US", "language_code": "", "popular_shelves": [{"count": "3", "name": "to-read"}, {"count": "1", "name": "p"}, {"count": "1", "name": "collection"}, {"count": "1", "name": "w-c-fields"}, {"count": "1", "name": "biography"}], "asin": "", "is_ebook": "false", "average_rating": "4.00", "kindle_asin": "", "similar_books": [], "description": "", "format": "Paperback", "link": "https://www.goodreads.com/book/show/5333265-w-c-fields", "authors": [{"author_id": "604031", "role": ""}], "publisher": "St. Martin\'s Press", "num_pages": "256", "publication_day": "1", "isbn13": "9780312853129", "publication_month": "9", "edition_information": "", "publication_year": "1984", "url": "https://www.goodreads.com/book/show/5333265-w-c-fields", "image_url": "https://images.gr-assets.com/books/1310220028m/5333265.jpg", "book_id": "5333265", "ratings_count": "3", "work_id": "5400751", "title": "W.C. Fields: A Life on Film", "title_without_series": "W.C. Fields: A Life on Film"}\n'

# %%
import json
json.loads(line)
# Out:
# {'isbn': '0312853122',
#  'text_reviews_count': '1',
#  'series': [],
#  'country_code': 'US',
#  'language_code': '',
#  'popular_shelves': [{'count': '3', 'name': 'to-read'},
#   {'count': '1', 'name': 'p'},
#   {'count': '1', 'name': 'collection'},
#   {'count': '1', 'name': 'w-c-fields'},
#   {'count': '1', 'name': 'biography'}],
#  'asin': '',
#  'is_ebook': 'false',
#  'average_rating': '4.00',
#  'kindle_asin': '',
#  'similar_books': [],
#  'description': '',
#  'format': 'Paperback',
#  'link': 'https://www.goodreads.com/book/show/5333265-w-c-fields',
#  'authors': [{'author_id': '604031', 'role': ''}],
#  'publisher': "St. Martin's Press",
#  'num_pages': '256',
#  'publication_day': '1',
#  'isbn13': '9780312853129',
#  'publication_month': '9',
#  'edition_information': '',
#  'publication_year': '1984',
#  'url': 'https://www.goodreads.com/book/show/5333265-w-c-fields',
#  'image_url': 'https://images.gr-assets.com/books/1310220028m/5333265.jpg',
#  'book_id': '5333265',
#  'ratings_count': '3',
#  'work_id': '5400751',
#  'title': 'W.C. Fields: A Life on Film',
#  'title_without_series': 'W.C. Fields: A Life on Film'}

# %%
def parse_fields(line):
    data= json.loads(line)
    return {
        "book_id": data["book_id"],
        "title": data["title_without_series"],
        "ratings": data["ratings_count"],
        "url": data["url"],
        "cover_image": data["image_url"]
    }

# %%
book_titles=[]
with gzip.open("goodreads_books.json.gz", 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        fields = parse_fields(line)
        try:
            ratings=int(fields["ratings"])
        except ValueError:
            continue
        if ratings > 15:
            book_titles.append(fields)

# %%
import pandas as pd

# %%
titles = pd.DataFrame.from_dict(book_titles)

# %%
titles["ratings"]=pd.to_numeric(titles["ratings"])

# %%
titles["mod_title"]=titles["title"].str.replace("[^a-zA-Z0-9]","",regex=True)

# %%
titles
# Out:
#           book_id                                              title  ratings  \
# 0         7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...      140
# 1         6066819                               Best Friends Forever    51184
# 2          287141                      The Aeneid for Boys and Girls       46
# 3         6066812  All's Fairy in Love and War (Avalon: Web of Ma...       98
# 4          287149                               The Devil's Notebook      986
# ...           ...                                                ...      ...
# 1308952  17805813                      Ondine (Ondine Quartet, #0.5)      327
# 1308953    331839     Jacqueline Kennedy Onassis: Friend of the Arts       18
# 1308954   2685097                   The Spaniard's Blackmailed Bride      112
# 1308955   2342551           The Children's Classic Poetry Collection       36
# 1308956  22017381          101 Nights: Volume One (101 Nights, #1-3)       70
#
#                                                        url  \
# 0        https://www.goodreads.com/book/show/7327624-th...
# 1        https://www.goodreads.com/book/show/6066819-be...
# 2        https://www.goodreads.com/book/show/287141.The...
# 3        https://www.goodreads.com/book/show/6066812-al...
# 4        https://www.goodreads.com/book/show/287149.The...
# ...                                                    ...
# 1308952  https://www.goodreads.com/book/show/17805813-o...
# 1308953  https://www.goodreads.com/book/show/331839.Jac...
# 1308954  https://www.goodreads.com/book/show/2685097-th...
# 1308955  https://www.goodreads.com/book/show/2342551.Th...
# 1308956  https://www.goodreads.com/book/show/22017381-1...
#
#                                                cover_image  \
# 0        https://images.gr-assets.com/books/1304100136m...
# 1        https://s.gr-assets.com/assets/nophoto/book/11...
# 2        https://s.gr-assets.com/assets/nophoto/book/11...
# 3        https://images.gr-assets.com/books/1316637798m...
# 4        https://images.gr-assets.com/books/1328768789m...
# ...                                                    ...
# 1308952  https://images.gr-assets.com/books/1379766592m...
# 1308953  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308954  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308955  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308956  https://images.gr-assets.com/books/1398621236m...
#
#                                        mod_title
# 0        TheUnschooledWizardSunWolfandStarhawk12
# 1                             BestFriendsForever
# 2                       TheAeneidforBoysandGirls
# 3         AllsFairyinLoveandWarAvalonWebofMagic8
# 4                              TheDevilsNotebook
# ...                                          ...
# 1308952                    OndineOndineQuartet05
# 1308953  JacquelineKennedyOnassisFriendoftheArts
# 1308954             TheSpaniardsBlackmailedBride
# 1308955      TheChildrensClassicPoetryCollection
# 1308956            101NightsVolumeOne101Nights13
#
# [1308957 rows x 6 columns]

# %%
titles["mod_title"]=titles["mod_title"].str.lower()

# %%
titles["mod_title"]=titles["mod_title"].str.replace("\s+"," ",regex= True)

# %%
titles
# Out:
#           book_id                                              title  ratings  \
# 0         7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...      140
# 1         6066819                               Best Friends Forever    51184
# 2          287141                      The Aeneid for Boys and Girls       46
# 3         6066812  All's Fairy in Love and War (Avalon: Web of Ma...       98
# 4          287149                               The Devil's Notebook      986
# ...           ...                                                ...      ...
# 1308952  17805813                      Ondine (Ondine Quartet, #0.5)      327
# 1308953    331839     Jacqueline Kennedy Onassis: Friend of the Arts       18
# 1308954   2685097                   The Spaniard's Blackmailed Bride      112
# 1308955   2342551           The Children's Classic Poetry Collection       36
# 1308956  22017381          101 Nights: Volume One (101 Nights, #1-3)       70
#
#                                                        url  \
# 0        https://www.goodreads.com/book/show/7327624-th...
# 1        https://www.goodreads.com/book/show/6066819-be...
# 2        https://www.goodreads.com/book/show/287141.The...
# 3        https://www.goodreads.com/book/show/6066812-al...
# 4        https://www.goodreads.com/book/show/287149.The...
# ...                                                    ...
# 1308952  https://www.goodreads.com/book/show/17805813-o...
# 1308953  https://www.goodreads.com/book/show/331839.Jac...
# 1308954  https://www.goodreads.com/book/show/2685097-th...
# 1308955  https://www.goodreads.com/book/show/2342551.Th...
# 1308956  https://www.goodreads.com/book/show/22017381-1...
#
#                                                cover_image  \
# 0        https://images.gr-assets.com/books/1304100136m...
# 1        https://s.gr-assets.com/assets/nophoto/book/11...
# 2        https://s.gr-assets.com/assets/nophoto/book/11...
# 3        https://images.gr-assets.com/books/1316637798m...
# 4        https://images.gr-assets.com/books/1328768789m...
# ...                                                    ...
# 1308952  https://images.gr-assets.com/books/1379766592m...
# 1308953  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308954  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308955  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308956  https://images.gr-assets.com/books/1398621236m...
#
#                                        mod_title
# 0        theunschooledwizardsunwolfandstarhawk12
# 1                             bestfriendsforever
# 2                       theaeneidforboysandgirls
# 3         allsfairyinloveandwaravalonwebofmagic8
# 4                              thedevilsnotebook
# ...                                          ...
# 1308952                    ondineondinequartet05
# 1308953  jacquelinekennedyonassisfriendofthearts
# 1308954             thespaniardsblackmailedbride
# 1308955      thechildrensclassicpoetrycollection
# 1308956            101nightsvolumeone101nights13
#
# [1308957 rows x 6 columns]

# %%
titles = titles[titles["mod_title"].str.len() > 0]

# %%
titles.to_json("books_titles.json")

# %%
titles
# Out:
#           book_id                                              title  ratings  \
# 0         7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...      140
# 1         6066819                               Best Friends Forever    51184
# 2          287141                      The Aeneid for Boys and Girls       46
# 3         6066812  All's Fairy in Love and War (Avalon: Web of Ma...       98
# 4          287149                               The Devil's Notebook      986
# ...           ...                                                ...      ...
# 1308952  17805813                      Ondine (Ondine Quartet, #0.5)      327
# 1308953    331839     Jacqueline Kennedy Onassis: Friend of the Arts       18
# 1308954   2685097                   The Spaniard's Blackmailed Bride      112
# 1308955   2342551           The Children's Classic Poetry Collection       36
# 1308956  22017381          101 Nights: Volume One (101 Nights, #1-3)       70
#
#                                                        url  \
# 0        https://www.goodreads.com/book/show/7327624-th...
# 1        https://www.goodreads.com/book/show/6066819-be...
# 2        https://www.goodreads.com/book/show/287141.The...
# 3        https://www.goodreads.com/book/show/6066812-al...
# 4        https://www.goodreads.com/book/show/287149.The...
# ...                                                    ...
# 1308952  https://www.goodreads.com/book/show/17805813-o...
# 1308953  https://www.goodreads.com/book/show/331839.Jac...
# 1308954  https://www.goodreads.com/book/show/2685097-th...
# 1308955  https://www.goodreads.com/book/show/2342551.Th...
# 1308956  https://www.goodreads.com/book/show/22017381-1...
#
#                                                cover_image  \
# 0        https://images.gr-assets.com/books/1304100136m...
# 1        https://s.gr-assets.com/assets/nophoto/book/11...
# 2        https://s.gr-assets.com/assets/nophoto/book/11...
# 3        https://images.gr-assets.com/books/1316637798m...
# 4        https://images.gr-assets.com/books/1328768789m...
# ...                                                    ...
# 1308952  https://images.gr-assets.com/books/1379766592m...
# 1308953  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308954  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308955  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308956  https://images.gr-assets.com/books/1398621236m...
#
#                                        mod_title
# 0        theunschooledwizardsunwolfandstarhawk12
# 1                             bestfriendsforever
# 2                       theaeneidforboysandgirls
# 3         allsfairyinloveandwaravalonwebofmagic8
# 4                              thedevilsnotebook
# ...                                          ...
# 1308952                    ondineondinequartet05
# 1308953  jacquelinekennedyonassisfriendofthearts
# 1308954             thespaniardsblackmailedbride
# 1308955      thechildrensclassicpoetrycollection
# 1308956            101nightsvolumeone101nights13
#
# [1264933 rows x 6 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()

tfidf = vectorizer.fit_transform(titles["mod_title"])

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import re

def make_clickable(val):
    return '<a target="_blank" href="{}">Goodreads</a>'.format(val, val)

def show_image(val):
    return '<a href="{}"><img src="{}" width=50></img></a>'.format(val, val)

def search(query,vectorizer):
    processed = re.sub("[^a-zA-Z0-9 ]", "", query.lower())
    query_vec = vectorizer.transform([query])
    similarity = cosine_similarity(query_vec, tfidf).flatten()
    indices = np.argpartition(similarity, -10)[-10:]
    results = titles.iloc[indices]
    results = results.sort_values("ratings", ascending=False)
    
    return results.head(5).style.format({'url': make_clickable, 'cover_image': show_image})

# %%
search("harry potter", vectorizer)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a966a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a966a_level0_col0" class="col_heading level0 col0" >book_id</th>
#       <th id="T_a966a_level0_col1" class="col_heading level0 col1" >title</th>
#       <th id="T_a966a_level0_col2" class="col_heading level0 col2" >ratings</th>
#       <th id="T_a966a_level0_col3" class="col_heading level0 col3" >url</th>
#       <th id="T_a966a_level0_col4" class="col_heading level0 col4" >cover_image</th>
#       <th id="T_a966a_level0_col5" class="col_heading level0 col5" >mod_title</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a966a_level0_row0" class="row_heading level0 row0" >436268</th>
#       <td id="T_a966a_row0_col0" class="data row0 col0" >28587609</td>
#       <td id="T_a966a_row0_col1" class="data row0 col1" >Pull Me Close (The Panic, #1)</td>
#       <td id="T_a966a_row0_col2" class="data row0 col2" >1057</td>
#       <td id="T_a966a_row0_col3" class="data row0 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/28587609-pull-me-close">Goodreads</a></td>
#       <td id="T_a966a_row0_col4" class="data row0 col4" ><a href="https://images.gr-assets.com/books/1464110260m/28587609.jpg"><img src="https://images.gr-assets.com/books/1464110260m/28587609.jpg" width=50></img></a></td>
#       <td id="T_a966a_row0_col5" class="data row0 col5" >pullmeclosethepanic1</td>
#     </tr>
#     <tr>
#       <th id="T_a966a_level0_row1" class="row_heading level0 row1" >436267</th>
#       <td id="T_a966a_row1_col0" class="data row1 col0" >12373920</td>
#       <td id="T_a966a_row1_col1" class="data row1 col1" >Small Things with Great Love: Adventures in Loving Your Neighbor</td>
#       <td id="T_a966a_row1_col2" class="data row1 col2" >162</td>
#       <td id="T_a966a_row1_col3" class="data row1 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/12373920-small-things-with-great-love">Goodreads</a></td>
#       <td id="T_a966a_row1_col4" class="data row1 col4" ><a href="https://images.gr-assets.com/books/1327938640m/12373920.jpg"><img src="https://images.gr-assets.com/books/1327938640m/12373920.jpg" width=50></img></a></td>
#       <td id="T_a966a_row1_col5" class="data row1 col5" >smallthingswithgreatloveadventuresinlovingyourneighbor</td>
#     </tr>
#     <tr>
#       <th id="T_a966a_level0_row2" class="row_heading level0 row2" >436282</th>
#       <td id="T_a966a_row2_col0" class="data row2 col0" >2285901</td>
#       <td id="T_a966a_row2_col1" class="data row2 col1" >Dancing to Freedom: The True Story of Mao's Last Dancer</td>
#       <td id="T_a966a_row2_col2" class="data row2 col2" >150</td>
#       <td id="T_a966a_row2_col3" class="data row2 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/2285901.Dancing_to_Freedom">Goodreads</a></td>
#       <td id="T_a966a_row2_col4" class="data row2 col4" ><a href="https://images.gr-assets.com/books/1312053547m/2285901.jpg"><img src="https://images.gr-assets.com/books/1312053547m/2285901.jpg" width=50></img></a></td>
#       <td id="T_a966a_row2_col5" class="data row2 col5" >dancingtofreedomthetruestoryofmaoslastdancer</td>
#     </tr>
#     <tr>
#       <th id="T_a966a_level0_row3" class="row_heading level0 row3" >436269</th>
#       <td id="T_a966a_row3_col0" class="data row3 col0" >652851</td>
#       <td id="T_a966a_row3_col1" class="data row3 col1" >So This Is Christmas (Includes: The Protectors, #19)</td>
#       <td id="T_a966a_row3_col2" class="data row3 col2" >122</td>
#       <td id="T_a966a_row3_col3" class="data row3 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/652851.So_This_Is_Christmas">Goodreads</a></td>
#       <td id="T_a966a_row3_col4" class="data row3 col4" ><a href="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png"><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></a></td>
#       <td id="T_a966a_row3_col5" class="data row3 col5" >sothisischristmasincludestheprotectors19</td>
#     </tr>
#     <tr>
#       <th id="T_a966a_level0_row4" class="row_heading level0 row4" >436271</th>
#       <td id="T_a966a_row4_col0" class="data row4 col0" >652855</td>
#       <td id="T_a966a_row4_col1" class="data row4 col1" >Eddie and the Cruisers</td>
#       <td id="T_a966a_row4_col2" class="data row4 col2" >117</td>
#       <td id="T_a966a_row4_col3" class="data row4 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/652855.Eddie_and_the_Cruisers">Goodreads</a></td>
#       <td id="T_a966a_row4_col4" class="data row4 col4" ><a href="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png"><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></a></td>
#       <td id="T_a966a_row4_col5" class="data row4 col5" >eddieandthecruisers</td>
#     </tr>
#   </tbody>
# </table>
